# %%
def get_players_data(players, rows,index):
    '''helper function to parse player data on who were transferred in the English premier league '''
    club_list = ['Leicester City','Arsenal FC','Tottenham Hotspur','Manchester City',
             'Manchester United','Southampton FC','West Ham United','Liverpool FC',
            'Stoke City','Chelsea FC','Everton FC','Swansea City','Watford FC',
            'West Bromwich Albion','Crystal Palace','AFC Bournemouth','Sunderland AFC',
             'Burnley FC','Middlesbrough FC','Hull City']
    for row in rows[1:]:
        players_data = { }
        for (i,item) in  enumerate(row.find_all('td')):
                if i == 0:
                    parts = item.find('a')
                    players_data['p_name'] = parts.get('title')
                    #parts = item.find('a').get('href').split('/')
                    players_data['handle'] = parts.get('href').split('/')[1]
                    players_data['id'] = parts.get('id')
                if i == 1:
                    players_data['age'] = item.get_text()
                if i == 3:
                    players_data['position'] = item.get_text()
                if i == 5:
                    players_data['transfer_fee_pounds'] = item.get_text()
                if index%2 == 0:
                    players_data['transfer_status'] = 'in'
                else:
                    players_data['transfer_status'] = 'out'
                players_data['club'] = club_list[int(index/2)]
                
        players.append(players_data)

# %%
def fetch_data(players, year):
    ''' given a particular year , fetch transferred player data from English premier league'''
    url = 'http://www.transfermarkt.co.uk/premier-league/sommertransfers/wettbewerb/GB1/saison_id/%s.html' % (year)
    r = requests.get(url,headers={"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36"})
    html_doc = r.text
    soup = BeautifulSoup(html_doc)
    table= soup.find_all('div',{'class':"responsive-table"})
    for i in range(0,39):
        rows = table[i].find_all('tr')
        get_players_data(players, rows,i)
    #rows = table.find_all('tr' , {'class':"dunkel"})
    #get_players_data(players, rows[1:])

# %%
import requests
from bs4 import BeautifulSoup
year = 2016
players = []
fetch_data(players,year)
# Out:
# /home/peimengsui/anaconda3/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
def extend_data(players, new_players, year):
    for player in players:

        url = 'http://www.transfermarkt.co.uk/%s/profil/spieler/%s' % (player['handle'],player['id'])
        print(player['handle'])
        r = requests.get(url,headers={"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36"})
        html_doc = r.text
        soup = BeautifulSoup(html_doc)
        try:
            table = soup.find('table' , {'class':"items"})
            row = table.find_all('tr')[3]
        except Exception:
            pass
        
        for (i,item) in  enumerate(row.find_all('td',{'class':"zentriert"})):
            if i == 0:
                if item.get_text() != '-':
                    player['matches'] = item.get_text()
                else:
                    player['matches'] = 0
            if i == 1:
                if item.get_text() != '-':
                    player['goals'] = item.get_text()
                else:
                    player['goals'] = 0
            if i == 2:
                if item.get_text() != '-':
                    player['assists'] = item.get_text()
                else:
                    player['assists'] = 0
            if i == 3:
                if item.get_text() != '-':
                    player['minutes_per_goal'] = item.get_text()
                else:
                    player['minutes_per_goal'] = 0
            if i == 4:
                if item.get_text() != '-':
                    player['minutes'] = item.get_text()
                else:
                    player['minutes'] = 0
        new_players.append(player)

# %%
new_players = []
import pdb
extend_data(players, new_players, year)
# Out:
# islam-slimani
# /home/peimengsui/anaconda3/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# glenn-murray
# josh-ohanlon
# matt-ritchie
# tommy-elphick
# lee-tomlin
# tokelo-rantie
# eunan-okane
# shaun-macdonald
# josh-wakefield
# stephane-zubar
# jayden-stockley
# harry-cornick
# josh-carmichael
# baily-cargill
# glenn-murray
# rhoys-wiggins
# jack-wilshere
# nathan-ake
# sylvain-distin
# marius-adamonis
# juan-iturbe
# didier-ndong
# papy-djilobodji
# paddy-mcnair
# mika
# donald-love
# steven-pienaar
# javier-manquillo
# adnan-januzaj
# jason-denayer
# will-buckley
# adam-matthews
# joel-asoro
# victor-anichebe
# lynden-gooch
# emanuele-giaccherini
# steven-fletcher
# santiago-vergini
# charalampos-mavrias
# danny-graham
# younes-kaboul
# emanuele-giaccherini
# liam-bridcutt
# santiago-vergini
# valentin-roberge
# jordi-gomez
# danny-graham
# mikael-mandron
# steven-fletcher
# adam-matthews
# jeremain-lens
# will-buckley
# jason-denayer
# wes-brown
# adnan-januzaj
# charalampos-mavrias
# steve-harper
# ola-toivonen
# yann-mvila
# dame-ndoye
# jeff-hendrick
# steven-defour
# johann-berg-gudmundsson
# nick-pope
# jon-flanagan
# patrick-bamford
# tom-anderson
# chris-long
# fredrik-ulvestad
# danny-lafferty
# lloyd-dyer
# matt-gilks
# matthew-taylor
# joey-barton
# chris-long
# lukas-jutkiewicz
# fredrik-ulvestad
# rouwen-hennings
# danny-lafferty
# david-jones
# tom-anderson
# patrick-bamford
# jon-flanagan
# michael-duff
# marten-de-roon
# viktor-fischer
# antonio-barragan
# fabio
# bernardo-espinosa
# brad-guzan
# victor-valdes
# gaston-ramirez
# adama-traore
# alvaro-negredo
# calum-chambers
# alex-baptiste
# connor-ripley
# dael-fry
# adam-reach
# mustapha-carayol
# rhys-williams
# adam-jackson
# connor-ripley
# albert-adomah
# dael-fry
# alex-baptiste
# calum-chambers
# jonathan-woodgate
# kike-sola
# michael-agazzi
# ryan-mason
# david-marshall
# will-keane
# james-weir
# dieumerci-mbokani
# markus-henriksen

# %%
import pandas as pd
df = pd.DataFrame(new_players)

# %%
df.head()
# Out:
#   age assists            club goals             handle      id matches  \
# 0  28       1  Leicester City     2      islam-slimani  174915       5
# 1  23       0  Leicester City     2         ahmed-musa  168337       7
# 2  24       0  Leicester City     0     nampalys-mendy  111051       1
# 3  19       0  Leicester City     0   bartosz-kapustka  246579       2
# 4  27       1  Leicester City     5  ron-robert-zieler   21327       3
#
#   minutes minutes_per_goal             p_name            position  \
# 0     356              178      Islam Slimani      Centre Forward
# 1     368              184         Ahmed Musa      Centre Forward
# 2      53                0     Nampalys Mendy  Defensive Midfield
# 3      61                0   Bartosz Kapustka  Attacking Midfield
# 4     NaN              213  Ron-Robert Zieler              Keeper
#
#   transfer_fee_pounds transfer_status
# 0             £18.70m              in
# 1             £15.30m              in
# 2              £6.38m              in
# 3              £4.25m              in
# 4              £6.80m              in

# %%
df.to_csv('data.csv')

# %%
# dump data from source to pkl files - to be run just once  
import pickle,requests
from bs4 import BeautifulSoup
import requests , re
players = []
years = ['2016']
for year in years :

    #year = '2012'
    fetch_data(players, year)
    new_players = []
    extend_data(players, new_players, year)
    f_name = "players_data_" + year +".pkl"
    pickle.dump( new_players, open( f_name, "wb" ) )
    #print new_players[0]

#pickle.dump( new_players, open( "players_data_2012.pkl", "wb" ) )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-0edab7574f79> in <module>()
#       8
#       9     #year = '2012'
# ---> 10     fetch_data(players, year)
#      11     new_players = []
#      12     extend_data(players, new_players, year)
#
# <ipython-input-76-26f2cca9f907> in fetch_data(players, year)
#       2     ''' given a particular year , fetch transferred player data from English premier league'''
#       3     url = 'http://www.transfermarkt.co.uk/premier-league/sommertransfers/wettbewerb/GB1/saison_id/%s.html' % (year)
# ----> 4     r = requests.get(url,headers={"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36"})
#       5     html_doc = r.text
#       6     soup = BeautifulSoup(html_doc)
#
# /home/peimengsui/anaconda3/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      69
#      70     kwargs.setdefault('allow_redirects', True)
# ---> 71     return request('get', url, params=params, **kwargs)
#      72
#      73
#
# /home/peimengsui/anaconda3/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      55     # cases, and look like a memory leak in others.
#      56     with sessions.Session() as session:
# ---> 57         return session.request(method=method, url=url, **kwargs)
#      58
#      59
#
# /home/peimengsui/anaconda3/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# /home/peimengsui/anaconda3/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     583
#     584         # Send the request
# --> 585         r = adapter.send(request, **kwargs)
#     586
#     587         # Total elapsed time of the request (approximately)
#
# /home/peimengsui/anaconda3/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     401                     decode_content=False,
#     402                     retries=self.max_retries,
# --> 403                     timeout=timeout
#     404                 )
#     405
#
# /home/peimengsui/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     576                                                   timeout=timeout_obj,
#     577                                                   body=body, headers=headers,
# --> 578                                                   chunked=chunked)
#     579
#     580             # If we're going to release the connection in ``finally:``, then
#
# /home/peimengsui/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     360             conn.request_chunked(method, url, **httplib_request_kw)
#     361         else:
# --> 362             conn.request(method, url, **httplib_request_kw)
#     363
#     364         # Reset the timeout for the recv() on the socket
#
# /home/peimengsui/anaconda3/lib/python3.5/http/client.py in request(self, method, url, body, headers)
#    1104     def request(self, method, url, body=None, headers={}):
#    1105         """Send a complete request to the server."""
# -> 1106         self._send_request(method, url, body, headers)
#    1107
#    1108     def _set_content_length(self, body, method):
#
# /home/peimengsui/anaconda3/lib/python3.5/http/client.py in _send_request(self, method, url, body, headers)
#    1149             # default charset of iso-8859-1.
#    1150             body = _encode(body, 'body')
# -> 1151         self.endheaders(body)
#    1152
#    1153     def getresponse(self):
#
# /home/peimengsui/anaconda3/lib/python3.5/http/client.py in endheaders(self, message_body)
#    1100         else:
#    1101             raise CannotSendHeader()
# -> 1102         self._send_output(message_body)
#    1103
#    1104     def request(self, method, url, body=None, headers={}):
#
# /home/peimengsui/anaconda3/lib/python3.5/http/client.py in _send_output(self, message_body)
#     932         del self._buffer[:]
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#     936             self.send(message_body)
#
# /home/peimengsui/anaconda3/lib/python3.5/http/client.py in send(self, data)
#     875         if self.sock is None:
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#     879                 raise NotConnected()
#
# /home/peimengsui/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     165
#     166     def connect(self):
# --> 167         conn = self._new_conn()
#     168         self._prepare_conn(conn)
#     169
#
# /home/peimengsui/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     140         try:
#     141             conn = connection.create_connection(
# --> 142                 (self.host, self.port), self.timeout, **extra_kw)
#     143
#     144         except SocketTimeout as e:
#
# /home/peimengsui/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      65         host = host.strip('[]')
#      66     err = None
# ---> 67     for res in socket.getaddrinfo(host, port, 0, socket.SOCK_STREAM):
#      68         af, socktype, proto, canonname, sa = res
#      69         sock = None
#
# /home/peimengsui/anaconda3/lib/python3.5/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     730     # and socket type values to enum constants.
#     731     addrlist = []
# --> 732     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     733         af, socktype, proto, canonname, sa = res
#     734         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:
